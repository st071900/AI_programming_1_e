# %% [markdown]
# *Display something*
#
# ```
#
# First value:1
#
# ```

# %%
'''
print a value
'''
print('First value: 1')
# Out:
# First value: 1

# %% [markdown]
# **Calling a function 'sort'**
#
# 1. Make a list of
#
# ```
# Numbers=[4,3,2,1]
# ```
# 2. Use the function `sort()`to sort the Numbers.
# 3.Display by using`print`

# %%
Numbers=[4,3,2,1]
Numbers.sort()
print(Numbers)
# Out:
# [1, 2, 3, 4]
